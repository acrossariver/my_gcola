# %% [markdown]
# <a href="https://colab.research.google.com/github/acrossariver/my_gcola/blob/main/%E8%87%AA%E4%BD%9C%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%8B%E3%83%B3%E3%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 日経２２５スクリーニング

# %%
import yfinance as yf
import pandas as pd
import datetime
import requests
import time

# 検索条件
MAX_PER = 15  # 15倍
MAX_PBR = 3.0  # 3.0以下
MIN_UP_CHANGE_RATE = 0.10  # 10%以上の上昇
MIN_DOWN_CHANGE_RATE = -0.05  # 5%以上の下落
MIN_DIVIDEND_YIELD = 2.00  # 2%以上の配当利回り
DAYS = 31 #過去何日から起算しての変化率か？

import pandas as pd

def get_nikkei225_tickers():
    # CSVファイルのURL
    url = "https://raw.githubusercontent.com/nakachan-ing/finance-streamlit/master/nikkei.csv"

    # CSVファイルをpandasで読み込む (shift_jisエンコーディングを指定)
    try:
        df = pd.read_csv(url, encoding='shift_jis')
    except Exception as e:
        print(f"CSVファイルの読み込みエラー: {e}")
        return []

    # データフレームの内容を確認
    #print(df.head())  # 最初の5行を表示

    # 銘柄コードを抽出し、'.T'を追加
    tickers = df['コード'].astype(str).apply(lambda x: x + '.T').tolist()

    return tickers

# 銘柄コードを取得
tickers = get_nikkei225_tickers()

print(f"取得した銘柄数: {len(tickers)}")



# 上昇・下落銘柄を格納するリスト
up_results = []
down_results = []

# スクリーニング処理
for ticker in tickers:
    try:
        stock = yf.Ticker(ticker)
        info = stock.info
        per = info.get("trailingPE", None)
        pbr = info.get("priceToBook", None)
        dividend_yield = info.get("dividendYield", None)

        if per is None or pbr is None or dividend_yield is None:
            continue

        # 配当利回りとPER、PBRの条件を満たしている銘柄
        if dividend_yield >= MIN_DIVIDEND_YIELD and per <= MAX_PER and pbr <= MAX_PBR:
            # 過去2週間の株価取得
            end = datetime.datetime.today()
            start = end - datetime.timedelta(days=DAYS)
            hist = stock.history(start=start, end=end)

            if len(hist) < 2:
                continue

            start_price = hist['Close'].iloc[0]
            end_price = hist['Close'].iloc[-1]
            change_rate = (end_price - start_price) / start_price

            # 上昇銘柄
            if change_rate >= MIN_UP_CHANGE_RATE:
                up_results.append({
                    "銘柄コード": ticker,
                    "PER": per,
                    "PBR": pbr,
                    "配当利回り": f"{dividend_yield:.2f}%",
                    "株価変化率": f"{change_rate * 100:.2f}%",  # Rename the key to "株価変化率"
                    "上昇/下降": "上昇"
                })
            # 下落銘柄
            elif change_rate <= MIN_DOWN_CHANGE_RATE:
                down_results.append({
                    "銘柄コード": ticker,
                    "PER": per,
                    "PBR": pbr,
                    "配当利回り": f"{dividend_yield:.2f}%",
                    "株価変化率": f"{change_rate * 100:.2f}%",  # Rename the key to "株価変化率"
                    "上昇/下降": "下降"
                })

        # time.sleep(1.5)  # アクセス制限回避のためにスリープ
    except Exception as e:
        print(f"エラー発生: {ticker}, {e}")

#過去何日前から起算して
print(f"過去{DAYS}日前から起算して")

# 銘柄コードと銘柄名の対応表を作成
df_name_map = pd.read_csv("https://raw.githubusercontent.com/nakachan-ing/finance-streamlit/master/nikkei.csv", encoding='shift_jis')
df_name_map['銘柄コード'] = df_name_map['コード'].astype(str) + ".T"
df_name_map = df_name_map[['銘柄コード', '銘柄名']]

# 上昇銘柄のデータフレーム
df_up = pd.DataFrame(up_results)
df_up = pd.merge(df_up, df_name_map, on='銘柄コード', how='left')

# 表示順を調整（銘柄コードと銘柄名を先頭に）
columns = ['銘柄コード', '銘柄名'] + [col for col in df_up.columns if col not in ['銘柄コード', '銘柄名']]
df_up = df_up[columns]

print(f"\n◎{MIN_UP_CHANGE_RATE * 100:.0f}%以上上昇した銘柄数: {len(df_up)}")
df_up = df_up.sort_values(by="株価変化率", ascending=False).reset_index(drop=True)
display(df_up)

# 下落銘柄のデータフレーム
df_down = pd.DataFrame(down_results)
df_down['株価変化率_num'] = df_down['株価変化率'].str.replace('%', '').astype(float)
df_down = df_down.sort_values(by="株価変化率_num").reset_index(drop=True)
df_down = df_down.drop(columns=["株価変化率_num"])

df_down = pd.merge(df_down, df_name_map, on='銘柄コード', how='left')

columns = ['銘柄コード', '銘柄名'] + [col for col in df_down.columns if col not in ['銘柄コード', '銘柄名']]
df_down = df_down[columns]

print(f"\n◎{MIN_DOWN_CHANGE_RATE * 100:.0f}%以上下落した銘柄数: {len(df_down)}")
display(df_down)
# Out:
# 取得した銘柄数: 225
# 過去31日前から起算して
#
# ◎10%以上上昇した銘柄数: 3
#     銘柄コード  銘柄名        PER       PBR  配当利回り   株価変化率 上昇/下降
# 0  1803.T  清水建  13.849787  1.229313  2.49%  15.22%    上昇
# 1  1801.T  大成建  13.369059  1.522885  3.82%  14.75%    上昇
# 2  1812.T   鹿島  14.224991  1.346475  3.49%  10.89%    上昇
# ◎-5%以上下落した銘柄数: 44
#      銘柄コード     銘柄名        PER       PBR  配当利回り    株価変化率 上昇/下降
# 0   6506.T     安川電  13.495008  1.772229  2.31%  -21.01%    下降
# 1   8308.T   りそなＨＤ  11.764707  0.908438  2.12%  -15.62%    下降
# 2   6724.T    エプソン  11.534279  0.781540  3.67%  -15.55%    下降
# 3   3099.T   三越伊勢丹  10.416667  1.114271  2.64%  -15.05%    下降
# 4   5019.T    出光興産  10.183017  0.636526  4.02%  -14.93%    下降
# 5   4004.T     昭電工   6.337145  0.700748  5.04%  -13.12%    下降
# 6   8604.T      野村   7.132949  0.674476  5.94%  -12.81%    下降
# 7   8331.T     千葉銀  13.071582  0.747251  3.60%  -12.54%    下降
# 8   8411.T   みずほＦＧ  10.080645  0.851589  3.66%  -12.37%    下降
# 9   8750.T  第一生命ＨＤ   2.440783  0.942491  3.34%  -12.14%    下降
# 10  8306.T   三菱ＵＦＪ  10.672128  1.008552  3.95%  -11.88%    下降
# 11  8316.T  三井住友ＦＧ  10.070497  0.865477  3.57%  -11.54%    下降
# 12  5020.T   ＥＮＥＯＳ   8.012725  0.596703  3.75%  -11.45%    下降
# 13  4631.T     ＤＩＣ  11.976274  0.635781  3.71%  -11.39%    下降
# 14  1605.T   ＩＮＰＥＸ   5.288169  0.453278  4.93%  -11.30%    下降
# 15  5706.T     三井金   3.512485  0.683915  3.88%  -11.00%    下降
# 16  5332.T    ＴＯＴＯ  12.484238  1.125619  2.89%  -10.99%    下降
# 17  5801.T     古河電  10.672354  0.956250  4.04%   -9.66%    下降
# 18  6326.T     クボタ   8.382264  0.768341  3.02%   -9.56%    下降
# 19  7201.T     日産自  12.049209  0.210100  4.87%   -9.48%    下降
# 20  6988.T     日東電  12.658422  1.648675  2.42%   -9.43%    下降
# 21  6752.T  パナソニック  11.261040  0.764146  2.49%   -9.31%    下降
# 22  8233.T     高島屋  10.277933  0.706728  2.36%   -8.93%    下降
# 23  5101.T     浜ゴム   6.729533  0.560168  3.25%   -8.77%    下降
# 24  5802.T     住友電   9.451705  0.762499  3.63%   -8.50%    下降
# 25  5411.T     ＪＦＥ   8.375293  0.426053  5.95%   -8.17%    下降
# 26  7186.T  コンコルディ  13.850751  0.809374  3.54%   -7.88%    下降
# 27  6178.T    日本郵政  13.870122  0.422016  3.64%   -7.87%    下降
# 28  6361.T      荏原  13.423166  2.022258  2.70%   -7.83%    下降
# 29  7269.T     スズキ   8.460216  1.085122  2.39%   -7.60%    下降
# 30  5711.T     三菱マ   5.425928  0.427423  4.43%   -7.59%    下降
# 31  7762.T    シチズン   8.209772  0.771722  5.45%   -7.51%    下降
# 32  7261.T     マツダ   4.163106  0.308127  6.84%   -6.92%    下降
# 33  6103.T    オークマ  14.025090  0.843749  3.15%   -6.89%    下降
# 34  3105.T   日清紡ＨＤ  12.953226  0.494275  4.25%   -6.87%    下降
# 35  4188.T  三菱ケミＨＤ  13.055714  0.540474  4.66%   -6.84%    下降
# 36  8354.T  ふくおかＦＧ  11.587372  0.707156  3.69%   -6.82%    下降
# 37  4021.T     日産化  13.106168  2.515071  3.95%   -6.53%    下降
# 38  8309.T  三井住友トラ   9.775091  0.793756  4.17%   -6.53%    下降
# 39  4183.T    三井化学  11.750987  0.674585  4.80%   -6.52%    下降
# 40  8253.T   クレセゾン   7.751938  0.712492  6.63%   -5.84%    下降
# 41  8795.T     Ｔ＆Ｄ  10.298574  1.076405  2.68%   -5.78%    下降
# 42  7272.T    ヤマハ発  10.225208  0.947630  4.44%   -5.54%    下降
# 43  6703.T     ＯＫＩ   3.159606  0.584370  6.43%   -5.18%    下降

# %% [markdown]
# # プライム市場スクリーニング

# %%
import yfinance as yf
import pandas as pd
import datetime
import requests
import random
from io import BytesIO

# 検索条件
MAX_PER = 15  # 15倍
MAX_PBR = 3.0  # 3.0以下
MIN_UP_CHANGE_RATE = 0.10  # 10%以上の上昇
MIN_DOWN_CHANGE_RATE = -0.05  # 5%以上の下落
MIN_DIVIDEND_YIELD = 4.00  # 4%以上の配当利回り
DAYS = 31 #過去何日から起算しての変化率か？
PRIME_RANDOM = 333 # ランダムに絞り込むプライム市場の銘柄数

# カスタムヘッダーを定義
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# === JPXのExcelファイルから東証プライム銘柄を取得 ===
xls_url = 'https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls'

# JPXのプライム市場の銘柄をExcelから取得
response = requests.get(xls_url)
xls_file = BytesIO(response.content)

# Excelファイルを読み込む（1枚目のシートを仮定）
df = pd.read_excel(xls_file, sheet_name=0)

# カラム名整形
df.columns = df.columns.str.strip()
df = df.dropna(subset=['コード'])  # コードがNaNの行を除外

# プライム市場に絞り込み
prime_df = df[df['市場・商品区分'].str.contains('プライム', na=False)].copy()

# 銘柄コードを yfinance 形式に
prime_df['銘柄コード'] = prime_df['コード'].astype(str).str.zfill(4) + '.T'

# 銘柄コードを yfinance 形式に（4桁 + ".T"）
tickers = prime_df['コード'].astype(str).str.zfill(4) + '.T'

# ランダムに333銘柄を抽出
tickers_list = random.sample(tickers.tolist(), PRIME_RANDOM)

# 取得銘柄数
print(f"取得銘柄数: {len(tickers_list)}")

# 上昇・下落銘柄を格納するリスト
up_results = []
down_results = []

# スクリーニング処理
for ticker in tickers_list:
    try:
        stock = yf.Ticker(ticker)
        info = stock.info
        per = info.get("trailingPE", None)
        pbr = info.get("priceToBook", None)
        dividend_yield = info.get("dividendYield", None)

        if per is None or pbr is None or dividend_yield is None:
            continue

        # 配当利回りとPER、PBRの条件を満たしている銘柄
        if per <= MAX_PER and pbr <= MAX_PBR and dividend_yield >= MIN_DIVIDEND_YIELD:
            # 過去2週間の株価取得
            end = datetime.datetime.today()
            start = end - datetime.timedelta(days=DAYS)
            hist = stock.history(start=start, end=end)

            if len(hist) < 2:
                continue

            start_price = hist['Close'].iloc[0]
            end_price = hist['Close'].iloc[-1]
            change_rate = (end_price - start_price) / start_price

            # 上昇銘柄
            if change_rate >= MIN_UP_CHANGE_RATE:
                up_results.append({
                    "銘柄コード": ticker,
                    "PER": per,
                    "PBR": pbr,
                    "配当利回り": f"{dividend_yield:.2f}%",
                    "株価変化率": f"{change_rate * 100:.2f}%",  # Rename the key to "株価変化率"
                    "上昇/下降": "上昇"
                })
            # 下落銘柄
            elif change_rate <= MIN_DOWN_CHANGE_RATE:
                down_results.append({
                    "銘柄コード": ticker,
                    "PER": per,
                    "PBR": pbr,
                    "配当利回り": f"{dividend_yield:.2f}%",
                    "株価変化率": f"{change_rate * 100:.2f}%",  # Rename the key to "株価変化率"
                    "上昇/下降": "下降"
                })

        # time.sleep(1.5)  # アクセス制限回避のためにスリープ
    except Exception as e:
        print(f"エラー発生: {ticker}, {e}")

# 過去何日前から起算して
print(f"過去{DAYS}日前から起算して")

# --- 銘柄コードと銘柄名の対応表を prime_df から取得 ---
prime_df['銘柄コード'] = prime_df['コード'].astype(str).str.zfill(4) + '.T'
df_name_map = prime_df[['銘柄コード', '銘柄名']].copy()

# 上昇銘柄のデータフレーム
df_up = pd.DataFrame(up_results)
df_up = pd.merge(df_up, df_name_map, on='銘柄コード', how='left')

# 表示順を調整（銘柄コードと銘柄名を先頭に）
columns = ['銘柄コード', '銘柄名'] + [col for col in df_up.columns if col not in ['銘柄コード', '銘柄名']]
df_up = df_up[columns]

print(f"\n◎{MIN_UP_CHANGE_RATE * 100:.0f}%以上上昇した銘柄数: {len(df_up)}")
df_up = df_up.sort_values(by="株価変化率", ascending=False).reset_index(drop=True)
display(df_up)

# 下落銘柄のデータフレーム
df_down = pd.DataFrame(down_results)
df_down['株価変化率_num'] = df_down['株価変化率'].str.replace('%', '').astype(float)
df_down = df_down.sort_values(by="株価変化率_num").reset_index(drop=True)
df_down = df_down.drop(columns=["株価変化率_num"])

df_down = pd.merge(df_down, df_name_map, on='銘柄コード', how='left')
columns = ['銘柄コード', '銘柄名'] + [col for col in df_down.columns if col not in ['銘柄コード', '銘柄名']]
df_down = df_down[columns]

print(f"\n◎{MIN_DOWN_CHANGE_RATE * 100:.0f}%以上下落した銘柄数: {len(df_down)}")
display(df_down)
# Out:
# 取得銘柄数: 333
# エラー発生: 2335.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8802.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1893.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6315.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8864.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6728.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2117.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4118.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8344.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3657.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4680.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3064.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5142.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9278.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6594.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6351.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6856.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7236.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6379.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8137.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6564.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4044.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9260.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6857.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4633.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6013.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3196.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3612.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2491.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7912.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4544.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6928.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3431.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7769.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5461.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7383.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5988.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6101.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1833.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7976.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9684.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3687.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7419.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8057.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4095.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6905.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9843.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9788.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6787.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7552.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3769.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6201.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6762.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9081.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6849.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8074.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1801.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9039.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7224.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6740.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6498.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1780.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3048.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9438.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7550.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8173.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7821.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8032.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2933.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1377.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2168.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6294.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4088.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7085.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2980.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7267.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3921.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7575.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6358.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3387.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9513.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7637.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4763.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9936.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3864.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6841.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3179.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5803.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4345.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7606.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1786.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4936.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7744.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8750.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6284.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8185.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8001.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9984.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6371.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6820.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9024.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6638.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7184.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1333.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5310.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7270.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7832.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3548.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9692.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9468.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1721.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7989.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3649.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7981.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3315.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8362.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9658.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4847.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4559.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3962.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7389.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6381.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5288.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3741.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4516.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9551.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2897.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6035.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1762.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6523.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9932.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 285A.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1964.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2791.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7936.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7172.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3632.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6095.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 1773.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6073.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3405.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 8160.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 9629.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6718.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 2802.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 5482.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 7915.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 4218.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6349.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 6952.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3863.T, Too Many Requests. Rate limited. Try after a while.
# エラー発生: 3197.T, Too Many Requests. Rate limited. Try after a while.
# ERROR:yfinance:401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/1301.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=1301.T&crumb=Edge%3A+Too+Many+Requests
# 過去31日前から起算して
#
# ◎10%以上上昇した銘柄数: 1
#     銘柄コード    銘柄名        PER       PBR  配当利回り   株価変化率 上昇/下降
# 0  1952.T  新日本空調  12.019342  1.430354  4.85%  18.16%    上昇
# ◎-5%以上下落した銘柄数: 14
#      銘柄コード               銘柄名        PER       PBR  配当利回り    株価変化率 上昇/下降
# 0   5019.T              出光興産  10.183017  0.636526  4.02%  -14.93%    下降
# 1   8570.T    イオンフィナンシャルサービス  12.936753  0.543159  4.53%  -11.33%    下降
# 2   6432.T             竹内製作所   8.210225  1.254798  7.78%  -10.90%    下降
# 3   7201.T             日産自動車  12.049209  0.210100  4.87%   -9.48%    下降
# 4   5195.T            バンドー化学  11.751315  0.716686  5.08%   -9.16%    下降
# 5   4041.T              日本曹達   8.431746  0.776121  4.52%   -8.51%    下降
# 6   9743.T               丹青社  12.675028  1.470378  5.76%   -7.47%    下降
# 7   4182.T            三菱瓦斯化学  12.562872  0.639124  4.60%   -6.56%    下降
# 8   6183.T  ベルシステム２４ホールディングス  10.893287  1.235197  5.09%   -6.43%    下降
# 9   5208.T             有沢製作所  11.764706  0.922160  6.48%   -6.36%    下降
# 10  1515.T              日鉄鉱業  12.165355  0.699019  4.08%   -6.08%    下降
# 11  6929.T           日本セラミック  14.903130  1.193666  9.26%   -5.92%    下降
# 12  7856.T              萩原工業  13.245276  0.670597  4.85%   -5.32%    下降
# 13  8511.T            日本証券金融  14.368256  1.016845  4.02%   -5.32%    下降
